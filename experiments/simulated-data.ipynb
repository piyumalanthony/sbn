# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import defaultdict
from matplotlib.colors import LogNorm
import matplotlib.gridspec as gridspec

# %%
from models import SBN
from utils import generate

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', 'gray']

# %%
taxa = list('ABCDEFGH')
all_tree = generate(taxa)

# %%
print(all_tree[1])
# Out:
#       /-F
#    /-|
#   |   \-C
#   |
#   |   /-G
#   |--|
# --|  |   /-D
#   |   \-|
#   |      \-A
#   |
#   |   /-B
#    \-|
#      |   /-H
#       \-|
#          \-E

# %%
tree_space_cap = len(all_tree)

# %%
for method in ['ccd', 'sbn-sa', 'sbn-em', 'sbn-em-alpha', 'freq']:
    if not os.path.exists('../results/simulation/' + method):
        os.makedirs('../results/simulation/' + method)
if not os.path.exists('../results/simulation/n-tree'):
    os.makedirs('../results/simulation/n-tree')

# %%
beta_v = [0.001, 0.002, 0.004, 0.008, 0.016, 0.032]
K_v = [500, 1000, 2000, 4000, 8000]

reg_lam = 50.0
nrep = 10
kl_div_mat = np.empty((nrep,6,5,5))

for rep in range(nrep):
    output_ccd = '../results/simulation/ccd/rep' + '{:02d}'.format(rep)
    output_sbn = '../results/simulation/sbn-sa/rep' + '{:02d}'.format(rep)
    output_sbn_em = '../results/simulation/sbn-em/rep' + '{:02d}'.format(rep)
    output_sbn_em_alpha = '../results/simulation/sbn-em-alpha/rep' + '{:02d}'.format(rep)
    output_freq = '../results/simulation/freq/rep' + '{:02d}'.format(rep)
    output_n_unique_tree = '../results/simulation/n-tree/rep' +'{:02d}'.format(rep)
    
    kl_div_ccd = open(output_ccd, 'w')
    kl_div_sbn = open(output_sbn, 'w')
    kl_div_sbn_em = open(output_sbn_em, 'w')
    kl_div_sbn_em_alpha = open(output_sbn_em_alpha, 'w')
    kl_div_freq = open(output_freq, 'w')
    n_unique_tree = open(output_n_unique_tree, 'w')
    
    kl_div_ccd.write(''.ljust(8) + '\t'.join([str(n_tree).ljust(6) for n_tree in K_v]) +'\n')
    kl_div_sbn.write(''.ljust(8) + '\t'.join([str(n_tree).ljust(6) for n_tree in K_v]) +'\n')
    kl_div_sbn_em.write(''.ljust(8) + '\t'.join([str(n_tree).ljust(6) for n_tree in K_v]) +'\n')
    kl_div_sbn_em_alpha.write(''.ljust(8) + '\t'.join([str(n_tree).ljust(6) for n_tree in K_v]) +'\n')
    kl_div_freq.write(''.ljust(8) + '\t'.join([str(n_tree).ljust(6) for n_tree in K_v]) +'\n')
    n_unique_tree.write(''.ljust(8) + '\t'.join([str(n_tree).ljust(6) for n_tree in K_v]) +'\n')
    
    kl_div_ccd.flush()
    kl_div_sbn.flush()
    kl_div_sbn_em.flush()
    kl_div_sbn_em_alpha.flush()
    kl_div_freq.flush()
    n_unique_tree.flush()
    
    for l, beta in enumerate(beta_v):
        kl_div_ccd.write('{:.3f}'.format(beta))
        kl_div_sbn.write('{:.3f}'.format(beta))
        kl_div_sbn_em.write('{:.3f}'.format(beta))
        kl_div_sbn_em_alpha.write('{:.3f}'.format(beta))
        kl_div_freq.write('{:.3f}'.format(beta))
        n_unique_tree.write('{:.3f}'.format(beta))
        
        for j, n_trees in enumerate(K_v):
            samp_freq = np.random.dirichlet(beta*np.ones(tree_space_cap))
            emp_tree_freq = {tree:samp_freq[i] for i, tree in enumerate(all_tree) if samp_freq[i]>1e-20}

            samp_trees = np.random.choice(all_tree, n_trees, p=samp_freq)

            # Use a hashable identifier for trees
            tree_hashes = [tree.get_topology_id() for tree in samp_trees]
            sample_tree_count_dict = defaultdict(int)
            for tree in samp_trees:
                sample_tree_count_dict[tree.get_topology_id()] += 1


            # Use numpy.unique on the hashes
            unique_hashes, samp_counts = np.unique(tree_hashes, return_counts=True)

            unique_samp_trees_dict = {tree.get_topology_id: tree for tree in samp_trees}
            unique_samp_trees = list(unique_samp_trees_dict.values())

            print(len(unique_samp_trees))
            print(sum(samp_counts))

            # unique_samp_trees, samp_counts = np.unique(list(samp_trees), return_counts=True)

            tree_id = {tree.get_topology_id():[tree] for tree in unique_samp_trees}

            ## todo: check for correctness of samp_counts order to be utilized.
            tree_count_dict = {tree.get_topology_id():sample_tree_count_dict[tree.get_topology_id()] for tree in unique_samp_trees}
            
            model = SBN(taxa, emp_tree_freq)
            print('SBN-EM training: rep {}, beta {}, K {}'.format(rep, beta, n_trees))
            model.bn_train_count(tree_count_dict, tree_id)
            
            kl_div = model.kl_div()
            kl_div_mat[rep, l, j, 0], kl_div_mat[rep, l, j, 1] = kl_div['ccd'], kl_div['bn']
            kl_div_mat[rep, l, j, 4] = kl_div['freq']

            logp = model.bn_em_count(tree_count_dict, tree_id, maxiter=200, abstol=1e-05, monitor=True, MAP=False)
            kl_div_mat[rep, l, j, 2] = model.kl_div(method='bn')['bn']

            model = SBN(taxa, emp_tree_freq, alpha=reg_lam/n_trees)  
            print('SBN-EM-ALPHA training: rep {}, beta {}, K {}'.format(rep, beta, n_trees))
            logp = model.bn_em_count(tree_count_dict, tree_id, maxiter=200, abstol=1e-05, monitor=True, MAP=True)
            kl_div_mat[rep, l, j, 3] = model.kl_div(method='bn', MAP=True)['bn']

            kl_div_ccd.write('\t{:.4f}'.format(kl_div_mat[rep, l, j, 0]))
            kl_div_sbn.write('\t{:.4f}'.format(kl_div_mat[rep, l, j, 1]))
            kl_div_sbn_em.write('\t{:.4f}'.format(kl_div_mat[rep, l, j, 2]))
            kl_div_sbn_em_alpha.write('\t{:.4f}'.format(kl_div_mat[rep, l, j, 3]))
            kl_div_freq.write('\t{:.4f}'.format(kl_div_mat[rep, l, j, 4]))
            n_unique_tree.write('\t'+str(len(samp_counts)).ljust(6))
            
            kl_div_ccd.flush()
            kl_div_sbn.flush()
            kl_div_sbn_em.flush()
            kl_div_sbn_em_alpha.flush()
            kl_div_freq.flush()
            n_unique_tree.flush()
        
        kl_div_ccd.write('\n')
        kl_div_sbn.write('\n')
        kl_div_sbn_em.write('\n')
        kl_div_sbn_em_alpha.write('\n')
        kl_div_freq.write('\n')
        n_unique_tree.write('\n')
        
    kl_div_ccd.close()
    kl_div_sbn.close()
    kl_div_sbn_em.close()
    kl_div_sbn_em_alpha.close()
    kl_div_freq.close()
    n_unique_tree.close()
# Out:
# 37
# 500
# SBN-EM training: rep 0, beta 0.001, K 500
# Iter: 1: current per tree log-likelihood -3.090871
# Iter: 2: current per tree log-likelihood -3.067103
# Iter: 3: current per tree log-likelihood -3.058445
# Iter: 4: current per tree log-likelihood -3.052956
# Iter: 5: current per tree log-likelihood -3.046186
# Iter: 6: current per tree log-likelihood -3.038732
# Iter: 7: current per tree log-likelihood -3.032374
# Iter: 8: current per tree log-likelihood -3.025294
# Iter: 9: current per tree log-likelihood -3.016716
# Iter: 10: current per tree log-likelihood -3.008271
# Iter: 11: current per tree log-likelihood -3.003628
# Iter: 12: current per tree log-likelihood -3.002818
# Iter: 13: current per tree log-likelihood -3.002797
# Iter: 14: current per tree log-likelihood -3.002797
# Iter: 15: current per tree log-likelihood -3.002797
# Iter: 16: current per tree log-likelihood -3.002797
# Iter: 17: current per tree log-likelihood -3.002797
# Iter: 18: current per tree log-likelihood -3.002797
# Iter: 19: current per tree log-likelihood -3.002797
# Iter: 20: current per tree log-likelihood -3.002797
# Iter: 21: current per tree log-likelihood -3.002797
# Iter: 22: current per tree log-likelihood -3.002797
# Iter: 23: current per tree log-likelihood -3.002797
# Iter: 24: current per tree log-likelihood -3.002797
# Iter: 25: current per tree log-likelihood -3.002797
# Iter: 26: current per tree log-likelihood -3.002797
# Iter: 27: current per tree log-likelihood -3.002797
# Iter: 28: current per tree log-likelihood -3.002797
# Iter: 29: current per tree log-likelihood -3.002797
# Iter: 30: current per tree log-likelihood -3.002797
# Iter: 31: current per tree log-likelihood -3.002797
# Iter: 32: current per tree log-likelihood -3.002797
# Iter: 33: current per tree log-likelihood -3.002797
# Iter: 34: current per tree log-likelihood -3.002797
# Iter: 35: current per tree log-likelihood -3.002797
# Iter: 36: current per tree log-likelihood -3.002797
# Iter: 37: current per tree log-likelihood -3.002797
# Iter: 38: current per tree log-likelihood -3.002797
# Iter: 39: current per tree log-likelihood -3.002797
# Iter: 40: current per tree log-likelihood -3.002797
# Iter: 41: current per tree log-likelihood -3.002797
# Iter: 42: current per tree log-likelihood -3.002797
# Iter: 43: current per tree log-likelihood -3.002797
# Iter: 44: current per tree log-likelihood -3.002797
# Iter: 45: current per tree log-likelihood -3.002797
# Iter: 46: current per tree log-likelihood -3.002797
# Iter: 47: current per tree log-likelihood -3.002797
# Iter: 48: current per tree log-likelihood -3.002797
# Iter: 49: current per tree log-likelihood -3.002797
# Iter: 50: current per tree log-likelihood -3.002797
# Iter: 51: current per tree log-likelihood -3.002797
# Iter: 52: current per tree log-likelihood -3.002797
# SBN-EM-ALPHA training: rep 0, beta 0.001, K 500
# Iter: 1: current per tree log-likelihood -3.806953
# Iter: 2: current per tree log-likelihood -3.786898
# Iter: 3: current per tree log-likelihood -3.780929
# Iter: 4: current per tree log-likelihood -3.777547
# Iter: 5: current per tree log-likelihood -3.773848
# Iter: 6: current per tree log-likelihood -3.769125
# Iter: 7: current per tree log-likelihood -3.764293
# Iter: 8: current per tree log-likelihood -3.759989
# Iter: 9: current per tree log-likelihood -3.755401
# Iter: 10: current per tree log-likelihood -3.750182
# Iter: 11: current per tree log-likelihood -3.744635
# Iter: 12: current per tree log-likelihood -3.739748
# Iter: 13: current per tree log-likelihood -3.736731
# Iter: 14: current per tree log-likelihood -3.735405
# Iter: 15: current per tree log-likelihood -3.734653
# Iter: 16: current per tree log-likelihood -3.734010
# Iter: 17: current per tree log-likelihood -3.733415
# Iter: 18: current per tree log-likelihood -3.732863
# Iter: 19: current per tree log-likelihood -3.732351
# Iter: 20: current per tree log-likelihood -3.731875
# Iter: 21: current per tree log-likelihood -3.731430
# Iter: 22: current per tree log-likelihood -3.731012
# Iter: 23: current per tree log-likelihood -3.730617
# Iter: 24: current per tree log-likelihood -3.730244
# Iter: 25: current per tree log-likelihood -3.729890
# Iter: 26: current per tree log-likelihood -3.729555
# Iter: 27: current per tree log-likelihood -3.729238
# Iter: 28: current per tree log-likelihood -3.728940
# Iter: 29: current per tree log-likelihood -3.728661
# Iter: 30: current per tree log-likelihood -3.728400
# Iter: 31: current per tree log-likelihood -3.728157
# Iter: 32: current per tree log-likelihood -3.727932
# Iter: 33: current per tree log-likelihood -3.727725
# Iter: 34: current per tree log-likelihood -3.727534
# Iter: 35: current per tree log-likelihood -3.727359
# Iter: 36: current per tree log-likelihood -3.727199
# Iter: 37: current per tree log-likelihood -3.727051
# Iter: 38: current per tree log-likelihood -3.726916
# Iter: 39: current per tree log-likelihood -3.726790
# Iter: 40: current per tree log-likelihood -3.726674
# Iter: 41: current per tree log-likelihood -3.726566
# Iter: 42: current per tree log-likelihood -3.726466
# Iter: 43: current per tree log-likelihood -3.726371
# Iter: 44: current per tree log-likelihood -3.726281
# Iter: 45: current per tree log-likelihood -3.726197
# Iter: 46: current per tree log-likelihood -3.726116
# Iter: 47: current per tree log-likelihood -3.726039
# Iter: 48: current per tree log-likelihood -3.725966
# Iter: 49: current per tree log-likelihood -3.725895
# Iter: 50: current per tree log-likelihood -3.725828
# Iter: 51: current per tree log-likelihood -3.725763
# Iter: 52: current per tree log-likelihood -3.725702
# Iter: 53: current per tree log-likelihood -3.725644
# Iter: 54: current per tree log-likelihood -3.725591
# Iter: 55: current per tree log-likelihood -3.725542
# Iter: 56: current per tree log-likelihood -3.725498
# Iter: 57: current per tree log-likelihood -3.725461
# Iter: 58: current per tree log-likelihood -3.725428
# Iter: 59: current per tree log-likelihood -3.725400
# Iter: 60: current per tree log-likelihood -3.725376
# Iter: 61: current per tree log-likelihood -3.725356
# Iter: 62: current per tree log-likelihood -3.725337
# Iter: 63: current per tree log-likelihood -3.725320
# Iter: 64: current per tree log-likelihood -3.725305
# Iter: 65: current per tree log-likelihood -3.725290
# Iter: 66: current per tree log-likelihood -3.725277
# Iter: 67: current per tree log-likelihood -3.725264
# Iter: 68: current per tree log-likelihood -3.725252
# Iter: 69: current per tree log-likelihood -3.725240
# Iter: 70: current per tree log-likelihood -3.725229
# Iter: 71: current per tree log-likelihood -3.725219
# Iter: 72: current per tree log-likelihood -3.725208
# Iter: 73: current per tree log-likelihood -3.725199
# 49
# 1000
# SBN-EM training: rep 0, beta 0.001, K 1000
# Iter: 1: current per tree log-likelihood -2.793112
# Iter: 2: current per tree log-likelihood -2.780470
# Iter: 3: current per tree log-likelihood -2.776888
# Iter: 4: current per tree log-likelihood -2.775993
# Iter: 5: current per tree log-likelihood -2.775209
# Iter: 6: current per tree log-likelihood -2.774387
# Iter: 7: current per tree log-likelihood -2.773511
# Iter: 8: current per tree log-likelihood -2.771943
# Iter: 9: current per tree log-likelihood -2.770000
# Iter: 10: current per tree log-likelihood -2.768200
# Iter: 11: current per tree log-likelihood -2.766117
# Iter: 12: current per tree log-likelihood -2.764094
# Iter: 13: current per tree log-likelihood -2.763072
# Iter: 14: current per tree log-likelihood -2.762928
# Iter: 15: current per tree log-likelihood -2.762926
# Iter: 16: current per tree log-likelihood -2.762926
# Iter: 17: current per tree log-likelihood -2.762926
# Iter: 18: current per tree log-likelihood -2.762926
# Iter: 19: current per tree log-likelihood -2.762926
# Iter: 20: current per tree log-likelihood -2.762926
# Iter: 21: current per tree log-likelihood -2.762926
# Iter: 22: current per tree log-likelihood -2.762926
# Iter: 23: current per tree log-likelihood -2.762926
# Iter: 24: current per tree log-likelihood -2.762926
# Iter: 25: current per tree log-likelihood -2.762926
# Iter: 26: current per tree log-likelihood -2.762926
# Iter: 27: current per tree log-likelihood -2.762926
# Iter: 28: current per tree log-likelihood -2.762926
# Iter: 29: current per tree log-likelihood -2.762926
# Iter: 30: current per tree log-likelihood -2.762926
# Iter: 31: current per tree log-likelihood -2.762926
# Iter: 32: current per tree log-likelihood -2.762926
# Iter: 33: current per tree log-likelihood -2.762926
# Iter: 34: current per tree log-likelihood -2.762926
# Iter: 35: current per tree log-likelihood -2.762926
# Iter: 36: current per tree log-likelihood -2.762926
# Iter: 37: current per tree log-likelihood -2.762926
# Iter: 38: current per tree log-likelihood -2.762926
# Iter: 39: current per tree log-likelihood -2.762926
# Iter: 40: current per tree log-likelihood -2.762926
# Iter: 41: current per tree log-likelihood -2.762926
# Iter: 42: current per tree log-likelihood -2.762926
# Iter: 43: current per tree log-likelihood -2.762926
# Iter: 44: current per tree log-likelihood -2.762926
# Iter: 45: current per tree log-likelihood -2.762926
# Iter: 46: current per tree log-likelihood -2.762926
# Iter: 47: current per tree log-likelihood -2.762926
# Iter: 48: current per tree log-likelihood -2.762926
# Iter: 49: current per tree log-likelihood -2.762924
# Iter: 50: current per tree log-likelihood -2.762917
# Iter: 51: current per tree log-likelihood -2.762891
# Iter: 52: current per tree log-likelihood -2.762789
# Iter: 53: current per tree log-likelihood -2.762411
# Iter: 54: current per tree log-likelihood -2.761278
# Iter: 55: current per tree log-likelihood -2.759285
# Iter: 56: current per tree log-likelihood -2.757666
# Iter: 57: current per tree log-likelihood -2.756721
# Iter: 58: current per tree log-likelihood -2.756271
# Iter: 59: current per tree log-likelihood -2.756198
# Iter: 60: current per tree log-likelihood -2.756196
# SBN-EM-ALPHA training: rep 0, beta 0.001, K 1000
# Iter: 1: current per tree log-likelihood -3.170148
# Iter: 2: current per tree log-likelihood -3.157785
# Iter: 3: current per tree log-likelihood -3.154078
# Iter: 4: current per tree log-likelihood -3.151400
# Iter: 5: current per tree log-likelihood -3.147749
# Iter: 6: current per tree log-likelihood -3.143678
# Iter: 7: current per tree log-likelihood -3.140457
# Iter: 8: current per tree log-likelihood -3.137895
# Iter: 9: current per tree log-likelihood -3.135545
# Iter: 10: current per tree log-likelihood -3.133674
# Iter: 11: current per tree log-likelihood -3.132724
# Iter: 12: current per tree log-likelihood -3.132231
# Iter: 13: current per tree log-likelihood -3.131795
# Iter: 14: current per tree log-likelihood -3.131382
# Iter: 15: current per tree log-likelihood -3.130987
# Iter: 16: current per tree log-likelihood -3.130606
# Iter: 17: current per tree log-likelihood -3.130237
# Iter: 18: current per tree log-likelihood -3.129878
# Iter: 19: current per tree log-likelihood -3.129528
# Iter: 20: current per tree log-likelihood -3.129186
# Iter: 21: current per tree log-likelihood -3.128851
# Iter: 22: current per tree log-likelihood -3.128522
# Iter: 23: current per tree log-likelihood -3.128199
# Iter: 24: current per tree log-likelihood -3.127880
# Iter: 25: current per tree log-likelihood -3.127566
# Iter: 26: current per tree log-likelihood -3.127257
# Iter: 27: current per tree log-likelihood -3.126951
# Iter: 28: current per tree log-likelihood -3.126649
# Iter: 29: current per tree log-likelihood -3.126351
# Iter: 30: current per tree log-likelihood -3.126057
# Iter: 31: current per tree log-likelihood -3.125766
# Iter: 32: current per tree log-likelihood -3.125480
# Iter: 33: current per tree log-likelihood -3.125198
# Iter: 34: current per tree log-likelihood -3.124920
# Iter: 35: current per tree log-likelihood -3.124649
# Iter: 36: current per tree log-likelihood -3.124384
# Iter: 37: current per tree log-likelihood -3.124127
# Iter: 38: current per tree log-likelihood -3.123878
# Iter: 39: current per tree log-likelihood -3.123637
# Iter: 40: current per tree log-likelihood -3.123406
# Iter: 41: current per tree log-likelihood -3.123184
# Iter: 42: current per tree log-likelihood -3.122970
# Iter: 43: current per tree log-likelihood -3.122767
# Iter: 44: current per tree log-likelihood -3.122573
# Iter: 45: current per tree log-likelihood -3.122389
# Iter: 46: current per tree log-likelihood -3.122215
# Iter: 47: current per tree log-likelihood -3.122051
# Iter: 48: current per tree log-likelihood -3.121898
# Iter: 49: current per tree log-likelihood -3.121755
# Iter: 50: current per tree log-likelihood -3.121622
# Iter: 51: current per tree log-likelihood -3.121500
# Iter: 52: current per tree log-likelihood -3.121387
# Iter: 53: current per tree log-likelihood -3.121283
# Iter: 54: current per tree log-likelihood -3.121187
# Iter: 55: current per tree log-likelihood -3.121100
# Iter: 56: current per tree log-likelihood -3.121020
# Iter: 57: current per tree log-likelihood -3.120946
# Iter: 58: current per tree log-likelihood -3.120879
# Iter: 59: current per tree log-likelihood -3.120817
# Iter: 60: current per tree log-likelihood -3.120760
# Iter: 61: current per tree log-likelihood -3.120707
# Iter: 62: current per tree log-likelihood -3.120659
# Iter: 63: current per tree log-likelihood -3.120614
# Iter: 64: current per tree log-likelihood -3.120572
# Iter: 65: current per tree log-likelihood -3.120534
# Iter: 66: current per tree log-likelihood -3.120498
# Iter: 67: current per tree log-likelihood -3.120465
# Iter: 68: current per tree log-likelihood -3.120434
# Iter: 69: current per tree log-likelihood -3.120405
# Iter: 70: current per tree log-likelihood -3.120379
# Iter: 71: current per tree log-likelihood -3.120354
# Iter: 72: current per tree log-likelihood -3.120331
# Iter: 73: current per tree log-likelihood -3.120309
# Iter: 74: current per tree log-likelihood -3.120289
# Iter: 75: current per tree log-likelihood -3.120271
# Iter: 76: current per tree log-likelihood -3.120253
# Iter: 77: current per tree log-likelihood -3.120237
# Iter: 78: current per tree log-likelihood -3.120222
# Iter: 79: current per tree log-likelihood -3.120208
# Iter: 80: current per tree log-likelihood -3.120195
# Iter: 81: current per tree log-likelihood -3.120183
# Iter: 82: current per tree log-likelihood -3.120171
# Iter: 83: current per tree log-likelihood -3.120160
# Iter: 84: current per tree log-likelihood -3.120150
# 52
# 2000
# SBN-EM training: rep 0, beta 0.001, K 2000
# Iter: 1: current per tree log-likelihood -3.150812
# Iter: 2: current per tree log-likelihood -3.139270
# Iter: 3: current per tree log-likelihood -3.136367
# Iter: 4: current per tree log-likelihood -3.135323
# Iter: 5: current per tree log-likelihood -3.134311
# Iter: 6: current per tree log-likelihood -3.132401
# Iter: 7: current per tree log-likelihood -3.128208
# Iter: 8: current per tree log-likelihood -3.117919
# Iter: 9: current per tree log-likelihood -3.091308
# Iter: 10: current per tree log-likelihood -3.029408
# Iter: 11: current per tree log-likelihood -2.950701
# Iter: 12: current per tree log-likelihood -2.917681
# Iter: 13: current per tree log-likelihood -2.913362
# Iter: 14: current per tree log-likelihood -2.912775
# Iter: 15: current per tree log-likelihood -2.912747
# Iter: 16: current per tree log-likelihood -2.912747
# Iter: 17: current per tree log-likelihood -2.912747
# Iter: 18: current per tree log-likelihood -2.912747
# Iter: 19: current per tree log-likelihood -2.912747
# Iter: 20: current per tree log-likelihood -2.912747
# Iter: 21: current per tree log-likelihood -2.912747
# Iter: 22: current per tree log-likelihood -2.912747
# Iter: 23: current per tree log-likelihood -2.912747
# Iter: 24: current per tree log-likelihood -2.912747
# Iter: 25: current per tree log-likelihood -2.912747
# Iter: 26: current per tree log-likelihood -2.912747
# Iter: 27: current per tree log-likelihood -2.912747
# Iter: 28: current per tree log-likelihood -2.912747
# Iter: 29: current per tree log-likelihood -2.912747
# Iter: 30: current per tree log-likelihood -2.912747
# Iter: 31: current per tree log-likelihood -2.912747
# Iter: 32: current per tree log-likelihood -2.912747
# Iter: 33: current per tree log-likelihood -2.912747
# Iter: 34: current per tree log-likelihood -2.912747
# Iter: 35: current per tree log-likelihood -2.912747
# Iter: 36: current per tree log-likelihood -2.912747
# Iter: 37: current per tree log-likelihood -2.912747
# Iter: 38: current per tree log-likelihood -2.912747
# Iter: 39: current per tree log-likelihood -2.912747
# Iter: 40: current per tree log-likelihood -2.912747
# Iter: 41: current per tree log-likelihood -2.912747
# Iter: 42: current per tree log-likelihood -2.912747
# Iter: 43: current per tree log-likelihood -2.912747
# Iter: 44: current per tree log-likelihood -2.912747
# Iter: 45: current per tree log-likelihood -2.912747
# Iter: 46: current per tree log-likelihood -2.912747
# Iter: 47: current per tree log-likelihood -2.912747
# Iter: 48: current per tree log-likelihood -2.912747
# Iter: 49: current per tree log-likelihood -2.912747
# Iter: 50: current per tree log-likelihood -2.912747
# Iter: 51: current per tree log-likelihood -2.912747
# Iter: 52: current per tree log-likelihood -2.912747
# SBN-EM-ALPHA training: rep 0, beta 0.001, K 2000
# Iter: 1: current per tree log-likelihood -3.362540
# Iter: 2: current per tree log-likelihood -3.352238
# Iter: 3: current per tree log-likelihood -3.349628
# Iter: 4: current per tree log-likelihood -3.348394
# Iter: 5: current per tree log-likelihood -3.347060
# Iter: 6: current per tree log-likelihood -3.344730
# Iter: 7: current per tree log-likelihood -3.340746
# Iter: 8: current per tree log-likelihood -3.334858
# Iter: 9: current per tree log-likelihood -3.324031
# Iter: 10: current per tree log-likelihood -3.293270
# Iter: 11: current per tree log-likelihood -3.224834
# Iter: 12: current per tree log-likelihood -3.155852
# Iter: 13: current per tree log-likelihood -3.136136
# Iter: 14: current per tree log-likelihood -3.135288
# Iter: 15: current per tree log-likelihood -3.135092
# Iter: 16: current per tree log-likelihood -3.134911
# Iter: 17: current per tree log-likelihood -3.134746
# Iter: 18: current per tree log-likelihood -3.134594
# Iter: 19: current per tree log-likelihood -3.134455
# Iter: 20: current per tree log-likelihood -3.134327
# Iter: 21: current per tree log-likelihood -3.134207
# Iter: 22: current per tree log-likelihood -3.134094
# Iter: 23: current per tree log-likelihood -3.133986
# Iter: 24: current per tree log-likelihood -3.133881
# Iter: 25: current per tree log-likelihood -3.133778
# Iter: 26: current per tree log-likelihood -3.133677
# Iter: 27: current per tree log-likelihood -3.133577
# Iter: 28: current per tree log-likelihood -3.133478
# Iter: 29: current per tree log-likelihood -3.133380
# Iter: 30: current per tree log-likelihood -3.133282
# Iter: 31: current per tree log-likelihood -3.133184
# Iter: 32: current per tree log-likelihood -3.133087
# Iter: 33: current per tree log-likelihood -3.132990
# Iter: 34: current per tree log-likelihood -3.132892
# Iter: 35: current per tree log-likelihood -3.132795
# Iter: 36: current per tree log-likelihood -3.132698
# Iter: 37: current per tree log-likelihood -3.132600
# Iter: 38: current per tree log-likelihood -3.132502
# Iter: 39: current per tree log-likelihood -3.132404
# Iter: 40: current per tree log-likelihood -3.132305
# Iter: 41: current per tree log-likelihood -3.132206
# Iter: 42: current per tree log-likelihood -3.132106
# Iter: 43: current per tree log-likelihood -3.132005
# Iter: 44: current per tree log-likelihood -3.131904
# Iter: 45: current per tree log-likelihood -3.131803
# Iter: 46: current per tree log-likelihood -3.131700
# Iter: 47: current per tree log-likelihood -3.131597
# Iter: 48: current per tree log-likelihood -3.131493
# Iter: 49: current per tree log-likelihood -3.131388
# Iter: 50: current per tree log-likelihood -3.131283
# Iter: 51: current per tree log-likelihood -3.131177
# Iter: 52: current per tree log-likelihood -3.131070
# Iter: 53: current per tree log-likelihood -3.130962
# Iter: 54: current per tree log-likelihood -3.130853
# Iter: 55: current per tree log-likelihood -3.130743
# Iter: 56: current per tree log-likelihood -3.130630
# Iter: 57: current per tree log-likelihood -3.130514
# Iter: 58: current per tree log-likelihood -3.130394
# Iter: 59: current per tree log-likelihood -3.130268
# Iter: 60: current per tree log-likelihood -3.130135
# Iter: 61: current per tree log-likelihood -3.129994
# Iter: 62: current per tree log-likelihood -3.129844
# Iter: 63: current per tree log-likelihood -3.129689
# Iter: 64: current per tree log-likelihood -3.129537
# Iter: 65: current per tree log-likelihood -3.129402
# Iter: 66: current per tree log-likelihood -3.129297
# Iter: 67: current per tree log-likelihood -3.129223
# Iter: 68: current per tree log-likelihood -3.129168
# Iter: 69: current per tree log-likelihood -3.129120
# Iter: 70: current per tree log-likelihood -3.129074
# Iter: 71: current per tree log-likelihood -3.129030
# Iter: 72: current per tree log-likelihood -3.128986
# Iter: 73: current per tree log-likelihood -3.128943
# Iter: 74: current per tree log-likelihood -3.128900
# Iter: 75: current per tree log-likelihood -3.128857
# Iter: 76: current per tree log-likelihood -3.128815
# Iter: 77: current per tree log-likelihood -3.128773
# Iter: 78: current per tree log-likelihood -3.128730
# Iter: 79: current per tree log-likelihood -3.128688
# Iter: 80: current per tree log-likelihood -3.128646
# Iter: 81: current per tree log-likelihood -3.128605
# Iter: 82: current per tree log-likelihood -3.128563
# Iter: 83: current per tree log-likelihood -3.128522
# Iter: 84: current per tree log-likelihood -3.128481
# Iter: 85: current per tree log-likelihood -3.128441
# Iter: 86: current per tree log-likelihood -3.128401
# Iter: 87: current per tree log-likelihood -3.128363
# Iter: 88: current per tree log-likelihood -3.128325
# Iter: 89: current per tree log-likelihood -3.128288
# Iter: 90: current per tree log-likelihood -3.128252
# Iter: 91: current per tree log-likelihood -3.128218
# Iter: 92: current per tree log-likelihood -3.128185
# Iter: 93: current per tree log-likelihood -3.128153
# Iter: 94: current per tree log-likelihood -3.128122
# Iter: 95: current per tree log-likelihood -3.128092
# Iter: 96: current per tree log-likelihood -3.128063
# Iter: 97: current per tree log-likelihood -3.128035
# Iter: 98: current per tree log-likelihood -3.128007
# Iter: 99: current per tree log-likelihood -3.127979
# Iter: 100: current per tree log-likelihood -3.127952
# Iter: 101: current per tree log-likelihood -3.127925
# Iter: 102: current per tree log-likelihood -3.127899
# Iter: 103: current per tree log-likelihood -3.127873
# Iter: 104: current per tree log-likelihood -3.127847
# Iter: 105: current per tree log-likelihood -3.127821
# Iter: 106: current per tree log-likelihood -3.127795
# Iter: 107: current per tree log-likelihood -3.127770
# Iter: 108: current per tree log-likelihood -3.127744
# Iter: 109: current per tree log-likelihood -3.127719
# Iter: 110: current per tree log-likelihood -3.127694
# Iter: 111: current per tree log-likelihood -3.127669
# Iter: 112: current per tree log-likelihood -3.127644
# Iter: 113: current per tree log-likelihood -3.127619
# Iter: 114: current per tree log-likelihood -3.127594
# Iter: 115: current per tree log-likelihood -3.127569
# Iter: 116: current per tree log-likelihood -3.127544
# Iter: 117: current per tree log-likelihood -3.127519
# Iter: 118: current per tree log-likelihood -3.127494
# Iter: 119: current per tree log-likelihood -3.127470
# Iter: 120: current per tree log-likelihood -3.127445
# Iter: 121: current per tree log-likelihood -3.127420
# Iter: 122: current per tree log-likelihood -3.127395
# Iter: 123: current per tree log-likelihood -3.127371
# Iter: 124: current per tree log-likelihood -3.127346
# Iter: 125: current per tree log-likelihood -3.127321
# Iter: 126: current per tree log-likelihood -3.127296
# Iter: 127: current per tree log-likelihood -3.127271
# Iter: 128: current per tree log-likelihood -3.127247
# Iter: 129: current per tree log-likelihood -3.127222
# Iter: 130: current per tree log-likelihood -3.127197
# Iter: 131: current per tree log-likelihood -3.127172
# Iter: 132: current per tree log-likelihood -3.127147
# Iter: 133: current per tree log-likelihood -3.127122
# Iter: 134: current per tree log-likelihood -3.127097
# Iter: 135: current per tree log-likelihood -3.127072
# Iter: 136: current per tree log-likelihood -3.127046
# Iter: 137: current per tree log-likelihood -3.127021
# Iter: 138: current per tree log-likelihood -3.126996
# Iter: 139: current per tree log-likelihood -3.126971
# Iter: 140: current per tree log-likelihood -3.126946
# Iter: 141: current per tree log-likelihood -3.126921
# Iter: 142: current per tree log-likelihood -3.126896
# Iter: 143: current per tree log-likelihood -3.126871
# Iter: 144: current per tree log-likelihood -3.126847
# Iter: 145: current per tree log-likelihood -3.126823
# Iter: 146: current per tree log-likelihood -3.126800
# Iter: 147: current per tree log-likelihood -3.126778
# Iter: 148: current per tree log-likelihood -3.126757
# Iter: 149: current per tree log-likelihood -3.126736
# Iter: 150: current per tree log-likelihood -3.126717
# Iter: 151: current per tree log-likelihood -3.126698
# Iter: 152: current per tree log-likelihood -3.126680
# Iter: 153: current per tree log-likelihood -3.126663
# Iter: 154: current per tree log-likelihood -3.126646
# Iter: 155: current per tree log-likelihood -3.126630
# Iter: 156: current per tree log-likelihood -3.126615
# Iter: 157: current per tree log-likelihood -3.126601
# Iter: 158: current per tree log-likelihood -3.126587
# Iter: 159: current per tree log-likelihood -3.126573
# Iter: 160: current per tree log-likelihood -3.126560
# Iter: 161: current per tree log-likelihood -3.126548
# Iter: 162: current per tree log-likelihood -3.126536
# Iter: 163: current per tree log-likelihood -3.126524
# Iter: 164: current per tree log-likelihood -3.126513
# Iter: 165: current per tree log-likelihood -3.126502
# Iter: 166: current per tree log-likelihood -3.126491
# Iter: 167: current per tree log-likelihood -3.126481
# Iter: 168: current per tree log-likelihood -3.126471
# 74
# 4000
# SBN-EM training: rep 0, beta 0.001, K 4000
# Iter: 1: current per tree log-likelihood -3.295088
# Iter: 2: current per tree log-likelihood -3.262935
# Iter: 3: current per tree log-likelihood -3.250570
# Iter: 4: current per tree log-likelihood -3.245004
# Iter: 5: current per tree log-likelihood -3.241300
# Iter: 6: current per tree log-likelihood -3.238123
# Iter: 7: current per tree log-likelihood -3.234475
# Iter: 8: current per tree log-likelihood -3.229101
# Iter: 9: current per tree log-likelihood -3.221381
# Iter: 10: current per tree log-likelihood -3.214355
# Iter: 11: current per tree log-likelihood -3.210992
# Iter: 12: current per tree log-likelihood -3.210218
# Iter: 13: current per tree log-likelihood -3.209906
# Iter: 14: current per tree log-likelihood -3.209578
# Iter: 15: current per tree log-likelihood -3.209265
# Iter: 16: current per tree log-likelihood -3.209054
# Iter: 17: current per tree log-likelihood -3.208914
# Iter: 18: current per tree log-likelihood -3.208774
# Iter: 19: current per tree log-likelihood -3.208623
# Iter: 20: current per tree log-likelihood -3.208457
# Iter: 21: current per tree log-likelihood -3.208275
# Iter: 22: current per tree log-likelihood -3.208074
# Iter: 23: current per tree log-likelihood -3.207849
# Iter: 24: current per tree log-likelihood -3.207596
# Iter: 25: current per tree log-likelihood -3.207307
# Iter: 26: current per tree log-likelihood -3.206974
# Iter: 27: current per tree log-likelihood -3.206584
# Iter: 28: current per tree log-likelihood -3.206118
# Iter: 29: current per tree log-likelihood -3.205553
# Iter: 30: current per tree log-likelihood -3.204858
# Iter: 31: current per tree log-likelihood -3.204013
# Iter: 32: current per tree log-likelihood -3.203086
# Iter: 33: current per tree log-likelihood -3.202365
# Iter: 34: current per tree log-likelihood -3.202120
# Iter: 35: current per tree log-likelihood -3.202103
# Iter: 36: current per tree log-likelihood -3.202103
# Iter: 37: current per tree log-likelihood -3.202103
# Iter: 38: current per tree log-likelihood -3.202103
# Iter: 39: current per tree log-likelihood -3.202103
# Iter: 40: current per tree log-likelihood -3.202103
# Iter: 41: current per tree log-likelihood -3.202103
# Iter: 42: current per tree log-likelihood -3.202103
# Iter: 43: current per tree log-likelihood -3.202103
# Iter: 44: current per tree log-likelihood -3.202103
# Iter: 45: current per tree log-likelihood -3.202103
# Iter: 46: current per tree log-likelihood -3.202103
# Iter: 47: current per tree log-likelihood -3.202103
# Iter: 48: current per tree log-likelihood -3.202103
# Iter: 49: current per tree log-likelihood -3.202103
# Iter: 50: current per tree log-likelihood -3.202102
# Iter: 51: current per tree log-likelihood -3.202102
# Iter: 52: current per tree log-likelihood -3.202100
# SBN-EM-ALPHA training: rep 0, beta 0.001, K 4000
# Iter: 1: current per tree log-likelihood -3.403494
# Iter: 2: current per tree log-likelihood -3.373927
# Iter: 3: current per tree log-likelihood -3.364054
# Iter: 4: current per tree log-likelihood -3.359938
# Iter: 5: current per tree log-likelihood -3.356217
# Iter: 6: current per tree log-likelihood -3.352076
# Iter: 7: current per tree log-likelihood -3.346371
# Iter: 8: current per tree log-likelihood -3.338497
# Iter: 9: current per tree log-likelihood -3.331647
# Iter: 10: current per tree log-likelihood -3.328313
# Iter: 11: current per tree log-likelihood -3.326968
# Iter: 12: current per tree log-likelihood -3.326208
# Iter: 13: current per tree log-likelihood -3.325803
# Iter: 14: current per tree log-likelihood -3.325448
# Iter: 15: current per tree log-likelihood -3.325134
# Iter: 16: current per tree log-likelihood -3.324892
# Iter: 17: current per tree log-likelihood -3.324680
# Iter: 18: current per tree log-likelihood -3.324463
# Iter: 19: current per tree log-likelihood -3.324234
# Iter: 20: current per tree log-likelihood -3.323991
# Iter: 21: current per tree log-likelihood -3.323731
# Iter: 22: current per tree log-likelihood -3.323452
# Iter: 23: current per tree log-likelihood -3.323149
# Iter: 24: current per tree log-likelihood -3.322817
# Iter: 25: current per tree log-likelihood -3.322451
# Iter: 26: current per tree log-likelihood -3.322041
# Iter: 27: current per tree log-likelihood -3.321576
# Iter: 28: current per tree log-likelihood -3.321041
# Iter: 29: current per tree log-likelihood -3.320418
# Iter: 30: current per tree log-likelihood -3.319696
# Iter: 31: current per tree log-likelihood -3.318897
# Iter: 32: current per tree log-likelihood -3.318150
# Iter: 33: current per tree log-likelihood -3.317703
# Iter: 34: current per tree log-likelihood -3.317578
# Iter: 35: current per tree log-likelihood -3.317531
# Iter: 36: current per tree log-likelihood -3.317489
# Iter: 37: current per tree log-likelihood -3.317448
# Iter: 38: current per tree log-likelihood -3.317408
# Iter: 39: current per tree log-likelihood -3.317369
# Iter: 40: current per tree log-likelihood -3.317330
# Iter: 41: current per tree log-likelihood -3.317292
# Iter: 42: current per tree log-likelihood -3.317255
# Iter: 43: current per tree log-likelihood -3.317218
# Iter: 44: current per tree log-likelihood -3.317182
# Iter: 45: current per tree log-likelihood -3.317146
# Iter: 46: current per tree log-likelihood -3.317111
# Iter: 47: current per tree log-likelihood -3.317076
# Iter: 48: current per tree log-likelihood -3.317042
# Iter: 49: current per tree log-likelihood -3.317009
# Iter: 50: current per tree log-likelihood -3.316977
# Iter: 51: current per tree log-likelihood -3.316945
# Iter: 52: current per tree log-likelihood -3.316914
# Iter: 53: current per tree log-likelihood -3.316884
# Iter: 54: current per tree log-likelihood -3.316855
# Iter: 55: current per tree log-likelihood -3.316827
# Iter: 56: current per tree log-likelihood -3.316800
# Iter: 57: current per tree log-likelihood -3.316773
# Iter: 58: current per tree log-likelihood -3.316747
# Iter: 59: current per tree log-likelihood -3.316722
# Iter: 60: current per tree log-likelihood -3.316697
# Iter: 61: current per tree log-likelihood -3.316672
# Iter: 62: current per tree log-likelihood -3.316648
# Iter: 63: current per tree log-likelihood -3.316623
# Iter: 64: current per tree log-likelihood -3.316599
# Iter: 65: current per tree log-likelihood -3.316575
# Iter: 66: current per tree log-likelihood -3.316551
# Iter: 67: current per tree log-likelihood -3.316527
# Iter: 68: current per tree log-likelihood -3.316503
# Iter: 69: current per tree log-likelihood -3.316480
# Iter: 70: current per tree log-likelihood -3.316456
# Iter: 71: current per tree log-likelihood -3.316432
# Iter: 72: current per tree log-likelihood -3.316409
# Iter: 73: current per tree log-likelihood -3.316386
# Iter: 74: current per tree log-likelihood -3.316364
# Iter: 75: current per tree log-likelihood -3.316342
# Iter: 76: current per tree log-likelihood -3.316321
# Iter: 77: current per tree log-likelihood -3.316300
# Iter: 78: current per tree log-likelihood -3.316279
# Iter: 79: current per tree log-likelihood -3.316258
# Iter: 80: current per tree log-likelihood -3.316238
# Iter: 81: current per tree log-likelihood -3.316218
# Iter: 82: current per tree log-likelihood -3.316198
# Iter: 83: current per tree log-likelihood -3.316178
# Iter: 84: current per tree log-likelihood -3.316159
# Iter: 85: current per tree log-likelihood -3.316139
# Iter: 86: current per tree log-likelihood -3.316119
# Iter: 87: current per tree log-likelihood -3.316100
# Iter: 88: current per tree log-likelihood -3.316080
# Iter: 89: current per tree log-likelihood -3.316061
# Iter: 90: current per tree log-likelihood -3.316041
# Iter: 91: current per tree log-likelihood -3.316022
# Iter: 92: current per tree log-likelihood -3.316003
# Iter: 93: current per tree log-likelihood -3.315984
# Iter: 94: current per tree log-likelihood -3.315965
# Iter: 95: current per tree log-likelihood -3.315946
# Iter: 96: current per tree log-likelihood -3.315927
# Iter: 97: current per tree log-likelihood -3.315908
# Iter: 98: current per tree log-likelihood -3.315889
# Iter: 99: current per tree log-likelihood -3.315870
# Iter: 100: current per tree log-likelihood -3.315852
# Iter: 101: current per tree log-likelihood -3.315833
# Iter: 102: current per tree log-likelihood -3.315815
# Iter: 103: current per tree log-likelihood -3.315796
# Iter: 104: current per tree log-likelihood -3.315778
# Iter: 105: current per tree log-likelihood -3.315759
# Iter: 106: current per tree log-likelihood -3.315741
# Iter: 107: current per tree log-likelihood -3.315722
# Iter: 108: current per tree log-likelihood -3.315704
# Iter: 109: current per tree log-likelihood -3.315686
# Iter: 110: current per tree log-likelihood -3.315668
# Iter: 111: current per tree log-likelihood -3.315649
# Iter: 112: current per tree log-likelihood -3.315631
# Iter: 113: current per tree log-likelihood -3.315613
# Iter: 114: current per tree log-likelihood -3.315594
# Iter: 115: current per tree log-likelihood -3.315576
# Iter: 116: current per tree log-likelihood -3.315558
# Iter: 117: current per tree log-likelihood -3.315539
# Iter: 118: current per tree log-likelihood -3.315521
# Iter: 119: current per tree log-likelihood -3.315503
# Iter: 120: current per tree log-likelihood -3.315484
# Iter: 121: current per tree log-likelihood -3.315466
# Iter: 122: current per tree log-likelihood -3.315447
# Iter: 123: current per tree log-likelihood -3.315429
# Iter: 124: current per tree log-likelihood -3.315410
# Iter: 125: current per tree log-likelihood -3.315392
# Iter: 126: current per tree log-likelihood -3.315373
# Iter: 127: current per tree log-likelihood -3.315354
# Iter: 128: current per tree log-likelihood -3.315336
# Iter: 129: current per tree log-likelihood -3.315317
# Iter: 130: current per tree log-likelihood -3.315298
# Iter: 131: current per tree log-likelihood -3.315279
# Iter: 132: current per tree log-likelihood -3.315260
# Iter: 133: current per tree log-likelihood -3.315241
# Iter: 134: current per tree log-likelihood -3.315221
# Iter: 135: current per tree log-likelihood -3.315202
# Iter: 136: current per tree log-likelihood -3.315182
# Iter: 137: current per tree log-likelihood -3.315163
# Iter: 138: current per tree log-likelihood -3.315143
# Iter: 139: current per tree log-likelihood -3.315123
# Iter: 140: current per tree log-likelihood -3.315102
# Iter: 141: current per tree log-likelihood -3.315082
# Iter: 142: current per tree log-likelihood -3.315061
# Iter: 143: current per tree log-likelihood -3.315040
# Iter: 144: current per tree log-likelihood -3.315019
# Iter: 145: current per tree log-likelihood -3.314998
# Iter: 146: current per tree log-likelihood -3.314976
# Iter: 147: current per tree log-likelihood -3.314954
# Iter: 148: current per tree log-likelihood -3.314932
# Iter: 149: current per tree log-likelihood -3.314910
# Iter: 150: current per tree log-likelihood -3.314888
# Iter: 151: current per tree log-likelihood -3.314866
# Iter: 152: current per tree log-likelihood -3.314844
# Iter: 153: current per tree log-likelihood -3.314823
# Iter: 154: current per tree log-likelihood -3.314803
# Iter: 155: current per tree log-likelihood -3.314783
# Iter: 156: current per tree log-likelihood -3.314765
# Iter: 157: current per tree log-likelihood -3.314749
# Iter: 158: current per tree log-likelihood -3.314733
# Iter: 159: current per tree log-likelihood -3.314717
# Iter: 160: current per tree log-likelihood -3.314702
# Iter: 161: current per tree log-likelihood -3.314688
# Iter: 162: current per tree log-likelihood -3.314674
# Iter: 163: current per tree log-likelihood -3.314659
# Iter: 164: current per tree log-likelihood -3.314645
# Iter: 165: current per tree log-likelihood -3.314631
# Iter: 166: current per tree log-likelihood -3.314617
# Iter: 167: current per tree log-likelihood -3.314603
# Iter: 168: current per tree log-likelihood -3.314589
# Iter: 169: current per tree log-likelihood -3.314575
# Iter: 170: current per tree log-likelihood -3.314562
# Iter: 171: current per tree log-likelihood -3.314548
# Iter: 172: current per tree log-likelihood -3.314534
# Iter: 173: current per tree log-likelihood -3.314521
# Iter: 174: current per tree log-likelihood -3.314507
# Iter: 175: current per tree log-likelihood -3.314494
# Iter: 176: current per tree log-likelihood -3.314480
# Iter: 177: current per tree log-likelihood -3.314467
# Iter: 178: current per tree log-likelihood -3.314454
# Iter: 179: current per tree log-likelihood -3.314440
# Iter: 180: current per tree log-likelihood -3.314427
# Iter: 181: current per tree log-likelihood -3.314414
# Iter: 182: current per tree log-likelihood -3.314401
# Iter: 183: current per tree log-likelihood -3.314388
# Iter: 184: current per tree log-likelihood -3.314375
# Iter: 185: current per tree log-likelihood -3.314362
# Iter: 186: current per tree log-likelihood -3.314349
# Iter: 187: current per tree log-likelihood -3.314336
# Iter: 188: current per tree log-likelihood -3.314323
# Iter: 189: current per tree log-likelihood -3.314311
# Iter: 190: current per tree log-likelihood -3.314298
# Iter: 191: current per tree log-likelihood -3.314285
# Iter: 192: current per tree log-likelihood -3.314273
# Iter: 193: current per tree log-likelihood -3.314260
# Iter: 194: current per tree log-likelihood -3.314248
# Iter: 195: current per tree log-likelihood -3.314235
# Iter: 196: current per tree log-likelihood -3.314223
# Iter: 197: current per tree log-likelihood -3.314211
# Iter: 198: current per tree log-likelihood -3.314198
# Iter: 199: current per tree log-likelihood -3.314186
# Iter: 200: current per tree log-likelihood -3.314174
# 68
# 8000
# SBN-EM training: rep 0, beta 0.001, K 8000
# Iter: 1: current per tree log-likelihood -2.894520
# Iter: 2: current per tree log-likelihood -2.873279
# Iter: 3: current per tree log-likelihood -2.867569
# Iter: 4: current per tree log-likelihood -2.863847
# Iter: 5: current per tree log-likelihood -2.858509
# Iter: 6: current per tree log-likelihood -2.851335
# Iter: 7: current per tree log-likelihood -2.842136
# Iter: 8: current per tree log-likelihood -2.833606
# Iter: 9: current per tree log-likelihood -2.830990
# Iter: 10: current per tree log-likelihood -2.830816
# Iter: 11: current per tree log-likelihood -2.830780
# Iter: 12: current per tree log-likelihood -2.830735
# Iter: 13: current per tree log-likelihood -2.830681
# Iter: 14: current per tree log-likelihood -2.830625
# Iter: 15: current per tree log-likelihood -2.830588
# Iter: 16: current per tree log-likelihood -2.830579
# Iter: 17: current per tree log-likelihood -2.830579
# Iter: 18: current per tree log-likelihood -2.830579
# Iter: 19: current per tree log-likelihood -2.830579
# Iter: 20: current per tree log-likelihood -2.830579
# Iter: 21: current per tree log-likelihood -2.830579
# Iter: 22: current per tree log-likelihood -2.830579
# Iter: 23: current per tree log-likelihood -2.830579
# Iter: 24: current per tree log-likelihood -2.830579
# Iter: 25: current per tree log-likelihood -2.830579
# Iter: 26: current per tree log-likelihood -2.830579
# Iter: 27: current per tree log-likelihood -2.830579
# Iter: 28: current per tree log-likelihood -2.830579
# Iter: 29: current per tree log-likelihood -2.830579
# Iter: 30: current per tree log-likelihood -2.830579
# Iter: 31: current per tree log-likelihood -2.830579
# Iter: 32: current per tree log-likelihood -2.830579
# Iter: 33: current per tree log-likelihood -2.830579
# Iter: 34: current per tree log-likelihood -2.830579
# Iter: 35: current per tree log-likelihood -2.830579
# Iter: 36: current per tree log-likelihood -2.830579
# Iter: 37: current per tree log-likelihood -2.830579
# Iter: 38: current per tree log-likelihood -2.830579
# Iter: 39: current per tree log-likelihood -2.830579
# Iter: 40: current per tree log-likelihood -2.830579
# Iter: 41: current per tree log-likelihood -2.830579
# Iter: 42: current per tree log-likelihood -2.830579
# Iter: 43: current per tree log-likelihood -2.830579
# Iter: 44: current per tree log-likelihood -2.830579
# Iter: 45: current per tree log-likelihood -2.830579
# Iter: 46: current per tree log-likelihood -2.830579
# Iter: 47: current per tree log-likelihood -2.830579
# Iter: 48: current per tree log-likelihood -2.830579
# Iter: 49: current per tree log-likelihood -2.830579
# Iter: 50: current per tree log-likelihood -2.830579
# Iter: 51: current per tree log-likelihood -2.830579
# Iter: 52: current per tree log-likelihood -2.830579
# SBN-EM-ALPHA training: rep 0, beta 0.001, K 8000
# Iter: 1: current per tree log-likelihood -2.952199
# Iter: 2: current per tree log-likelihood -2.932320
# Iter: 3: current per tree log-likelihood -2.927360
# Iter: 4: current per tree log-likelihood -2.924294
# Iter: 5: current per tree log-likelihood -2.919931
# Iter: 6: current per tree log-likelihood -2.912955
# Iter: 7: current per tree log-likelihood -2.903606
# Iter: 8: current per tree log-likelihood -2.894965
# Iter: 9: current per tree log-likelihood -2.892228
# Iter: 10: current per tree log-likelihood -2.892048
# Iter: 11: current per tree log-likelihood -2.891978
# Iter: 12: current per tree log-likelihood -2.891907
# Iter: 13: current per tree log-likelihood -2.891835
# Iter: 14: current per tree log-likelihood -2.891764
# Iter: 15: current per tree log-likelihood -2.891699
# Iter: 16: current per tree log-likelihood -2.891650
# Iter: 17: current per tree log-likelihood -2.891617
# Iter: 18: current per tree log-likelihood -2.891590
# Iter: 19: current per tree log-likelihood -2.891565
# Iter: 20: current per tree log-likelihood -2.891541
# Iter: 21: current per tree log-likelihood -2.891519
# Iter: 22: current per tree log-likelihood -2.891497
# Iter: 23: current per tree log-likelihood -2.891477
# Iter: 24: current per tree log-likelihood -2.891457
# Iter: 25: current per tree log-likelihood -2.891438
# Iter: 26: current per tree log-likelihood -2.891419
# Iter: 27: current per tree log-likelihood -2.891401
# Iter: 28: current per tree log-likelihood -2.891384
# Iter: 29: current per tree log-likelihood -2.891367
# Iter: 30: current per tree log-likelihood -2.891350
# Iter: 31: current per tree log-likelihood -2.891334
# Iter: 32: current per tree log-likelihood -2.891319
# Iter: 33: current per tree log-likelihood -2.891304
# Iter: 34: current per tree log-likelihood -2.891289
# Iter: 35: current per tree log-likelihood -2.891274
# Iter: 36: current per tree log-likelihood -2.891260
# Iter: 37: current per tree log-likelihood -2.891246
# Iter: 38: current per tree log-likelihood -2.891233
# Iter: 39: current per tree log-likelihood -2.891219
# Iter: 40: current per tree log-likelihood -2.891206
# Iter: 41: current per tree log-likelihood -2.891193
# Iter: 42: current per tree log-likelihood -2.891180
# Iter: 43: current per tree log-likelihood -2.891168
# Iter: 44: current per tree log-likelihood -2.891155
# Iter: 45: current per tree log-likelihood -2.891143
# Iter: 46: current per tree log-likelihood -2.891131
# Iter: 47: current per tree log-likelihood -2.891120
# Iter: 48: current per tree log-likelihood -2.891109
# Iter: 49: current per tree log-likelihood -2.891098
# Iter: 50: current per tree log-likelihood -2.891088
# Iter: 51: current per tree log-likelihood -2.891078
# Iter: 52: current per tree log-likelihood -2.891069
# 75
# 500
# SBN-EM training: rep 0, beta 0.002, K 500
# Iter: 1: current per tree log-likelihood -3.793550
# Iter: 2: current per tree log-likelihood -3.754387
# Iter: 3: current per tree log-likelihood -3.739728
# Iter: 4: current per tree log-likelihood -3.733334
# Iter: 5: current per tree log-likelihood -3.724442
# Iter: 6: current per tree log-likelihood -3.702749
# Iter: 7: current per tree log-likelihood -3.663217
# Iter: 8: current per tree log-likelihood -3.632198
# Iter: 9: current per tree log-likelihood -3.625394
# Iter: 10: current per tree log-likelihood -3.624413
# Iter: 11: current per tree log-likelihood -3.623517
# Iter: 12: current per tree log-likelihood -3.622837
# Iter: 13: current per tree log-likelihood -3.622624
# Iter: 14: current per tree log-likelihood -3.622611
# Iter: 15: current per tree log-likelihood -3.622611
# Iter: 16: current per tree log-likelihood -3.622611
# Iter: 17: current per tree log-likelihood -3.622611
# Iter: 18: current per tree log-likelihood -3.622611
# Iter: 19: current per tree log-likelihood -3.622611
# Iter: 20: current per tree log-likelihood -3.622611
# Iter: 21: current per tree log-likelihood -3.622611
# Iter: 22: current per tree log-likelihood -3.622611
# Iter: 23: current per tree log-likelihood -3.622611
# Iter: 24: current per tree log-likelihood -3.622611
# Iter: 25: current per tree log-likelihood -3.622611
# Iter: 26: current per tree log-likelihood -3.622611
# Iter: 27: current per tree log-likelihood -3.622611
# Iter: 28: current per tree log-likelihood -3.622611
# Iter: 29: current per tree log-likelihood -3.622611
# Iter: 30: current per tree log-likelihood -3.622611
# Iter: 31: current per tree log-likelihood -3.622611
# Iter: 32: current per tree log-likelihood -3.622611
# Iter: 33: current per tree log-likelihood -3.622611
# Iter: 34: current per tree log-likelihood -3.622611
# Iter: 35: current per tree log-likelihood -3.622611
# Iter: 36: current per tree log-likelihood -3.622611
# Iter: 37: current per tree log-likelihood -3.622611
# Iter: 38: current per tree log-likelihood -3.622611
# Iter: 39: current per tree log-likelihood -3.622611
# Iter: 40: current per tree log-likelihood -3.622611
# Iter: 41: current per tree log-likelihood -3.622611
# Iter: 42: current per tree log-likelihood -3.622611
# Iter: 43: current per tree log-likelihood -3.622611
# Iter: 44: current per tree log-likelihood -3.622611
# Iter: 45: current per tree log-likelihood -3.622611
# Iter: 46: current per tree log-likelihood -3.622611
# Iter: 47: current per tree log-likelihood -3.622611
# Iter: 48: current per tree log-likelihood -3.622611
# Iter: 49: current per tree log-likelihood -3.622611
# Iter: 50: current per tree log-likelihood -3.622611
# Iter: 51: current per tree log-likelihood -3.622611
# Iter: 52: current per tree log-likelihood -3.622611
# SBN-EM-ALPHA training: rep 0, beta 0.002, K 500
# Iter: 1: current per tree log-likelihood -4.590074
# Iter: 2: current per tree log-likelihood -4.556149
# Iter: 3: current per tree log-likelihood -4.544199
# Iter: 4: current per tree log-likelihood -4.535016
# Iter: 5: current per tree log-likelihood -4.520775
# Iter: 6: current per tree log-likelihood -4.494120
# Iter: 7: current per tree log-likelihood -4.461770
# Iter: 8: current per tree log-likelihood -4.448876
# Iter: 9: current per tree log-likelihood -4.446787
# Iter: 10: current per tree log-likelihood -4.445350
# Iter: 11: current per tree log-likelihood -4.444013
# Iter: 12: current per tree log-likelihood -4.442814
# Iter: 13: current per tree log-likelihood -4.441683
# ...
# Iter: 194: current per tree log-likelihood -6.357964
# Iter: 195: current per tree log-likelihood -6.357947
# Iter: 196: current per tree log-likelihood -6.357931
# Iter: 197: current per tree log-likelihood -6.357915
# Iter: 198: current per tree log-likelihood -6.357899
# Iter: 199: current per tree log-likelihood -6.357884
# Iter: 200: current per tree log-likelihood -6.357868
# 1040
# 8000
# SBN-EM training: rep 9, beta 0.032, K 8000
# Iter: 1: current per tree log-likelihood -6.987238
# Iter: 2: current per tree log-likelihood -6.948410
# Iter: 3: current per tree log-likelihood -6.926007
# Iter: 4: current per tree log-likelihood -6.891287
# Iter: 5: current per tree log-likelihood -6.823721
# Iter: 6: current per tree log-likelihood -6.723671
# Iter: 7: current per tree log-likelihood -6.614585
# Iter: 8: current per tree log-likelihood -6.521390
# Iter: 9: current per tree log-likelihood -6.455550
# Iter: 10: current per tree log-likelihood -6.412757
# Iter: 11: current per tree log-likelihood -6.387522
# Iter: 12: current per tree log-likelihood -6.374052
# Iter: 13: current per tree log-likelihood -6.366088
# Iter: 14: current per tree log-likelihood -6.360512
# Iter: 15: current per tree log-likelihood -6.356089
# Iter: 16: current per tree log-likelihood -6.352202
# Iter: 17: current per tree log-likelihood -6.348776
# Iter: 18: current per tree log-likelihood -6.345880
# Iter: 19: current per tree log-likelihood -6.343628
# Iter: 20: current per tree log-likelihood -6.341895
# Iter: 21: current per tree log-likelihood -6.340463
# Iter: 22: current per tree log-likelihood -6.339126
# Iter: 23: current per tree log-likelihood -6.337720
# Iter: 24: current per tree log-likelihood -6.336243
# Iter: 25: current per tree log-likelihood -6.334970
# Iter: 26: current per tree log-likelihood -6.333996
# Iter: 27: current per tree log-likelihood -6.333155
# Iter: 28: current per tree log-likelihood -6.332359
# Iter: 29: current per tree log-likelihood -6.331585
# Iter: 30: current per tree log-likelihood -6.330848
# Iter: 31: current per tree log-likelihood -6.330190
# Iter: 32: current per tree log-likelihood -6.329603
# Iter: 33: current per tree log-likelihood -6.329100
# Iter: 34: current per tree log-likelihood -6.328687
# Iter: 35: current per tree log-likelihood -6.328339
# Iter: 36: current per tree log-likelihood -6.328062
# Iter: 37: current per tree log-likelihood -6.327835
# Iter: 38: current per tree log-likelihood -6.327618
# Iter: 39: current per tree log-likelihood -6.327407
# Iter: 40: current per tree log-likelihood -6.327208
# Iter: 41: current per tree log-likelihood -6.327029
# Iter: 42: current per tree log-likelihood -6.326871
# Iter: 43: current per tree log-likelihood -6.326713
# Iter: 44: current per tree log-likelihood -6.326546
# Iter: 45: current per tree log-likelihood -6.326380
# Iter: 46: current per tree log-likelihood -6.326242
# Iter: 47: current per tree log-likelihood -6.326142
# Iter: 48: current per tree log-likelihood -6.326059
# Iter: 49: current per tree log-likelihood -6.325963
# Iter: 50: current per tree log-likelihood -6.325838
# Iter: 51: current per tree log-likelihood -6.325684
# Iter: 52: current per tree log-likelihood -6.325537
# Iter: 53: current per tree log-likelihood -6.325442
# Iter: 54: current per tree log-likelihood -6.325374
# Iter: 55: current per tree log-likelihood -6.325308
# Iter: 56: current per tree log-likelihood -6.325243
# Iter: 57: current per tree log-likelihood -6.325177
# Iter: 58: current per tree log-likelihood -6.325109
# Iter: 59: current per tree log-likelihood -6.325040
# Iter: 60: current per tree log-likelihood -6.324967
# Iter: 61: current per tree log-likelihood -6.324891
# Iter: 62: current per tree log-likelihood -6.324809
# Iter: 63: current per tree log-likelihood -6.324717
# Iter: 64: current per tree log-likelihood -6.324612
# Iter: 65: current per tree log-likelihood -6.324490
# Iter: 66: current per tree log-likelihood -6.324358
# Iter: 67: current per tree log-likelihood -6.324248
# Iter: 68: current per tree log-likelihood -6.324193
# Iter: 69: current per tree log-likelihood -6.324172
# Iter: 70: current per tree log-likelihood -6.324156
# Iter: 71: current per tree log-likelihood -6.324140
# Iter: 72: current per tree log-likelihood -6.324124
# Iter: 73: current per tree log-likelihood -6.324108
# Iter: 74: current per tree log-likelihood -6.324091
# Iter: 75: current per tree log-likelihood -6.324073
# Iter: 76: current per tree log-likelihood -6.324055
# Iter: 77: current per tree log-likelihood -6.324035
# Iter: 78: current per tree log-likelihood -6.324015
# Iter: 79: current per tree log-likelihood -6.323993
# Iter: 80: current per tree log-likelihood -6.323969
# Iter: 81: current per tree log-likelihood -6.323942
# Iter: 82: current per tree log-likelihood -6.323913
# Iter: 83: current per tree log-likelihood -6.323880
# Iter: 84: current per tree log-likelihood -6.323843
# Iter: 85: current per tree log-likelihood -6.323800
# Iter: 86: current per tree log-likelihood -6.323750
# Iter: 87: current per tree log-likelihood -6.323691
# Iter: 88: current per tree log-likelihood -6.323621
# Iter: 89: current per tree log-likelihood -6.323545
# Iter: 90: current per tree log-likelihood -6.323484
# Iter: 91: current per tree log-likelihood -6.323451
# Iter: 92: current per tree log-likelihood -6.323432
# Iter: 93: current per tree log-likelihood -6.323414
# Iter: 94: current per tree log-likelihood -6.323399
# Iter: 95: current per tree log-likelihood -6.323387
# Iter: 96: current per tree log-likelihood -6.323378
# SBN-EM-ALPHA training: rep 9, beta 0.032, K 8000
# Iter: 1: current per tree log-likelihood -7.059057
# Iter: 2: current per tree log-likelihood -7.021007
# Iter: 3: current per tree log-likelihood -7.000048
# Iter: 4: current per tree log-likelihood -6.967406
# Iter: 5: current per tree log-likelihood -6.902370
# Iter: 6: current per tree log-likelihood -6.804139
# Iter: 7: current per tree log-likelihood -6.695419
# Iter: 8: current per tree log-likelihood -6.602384
# Iter: 9: current per tree log-likelihood -6.538041
# Iter: 10: current per tree log-likelihood -6.496891
# Iter: 11: current per tree log-likelihood -6.472429
# Iter: 12: current per tree log-likelihood -6.460474
# Iter: 13: current per tree log-likelihood -6.453415
# Iter: 14: current per tree log-likelihood -6.447190
# Iter: 15: current per tree log-likelihood -6.440904
# Iter: 16: current per tree log-likelihood -6.435977
# Iter: 17: current per tree log-likelihood -6.432221
# Iter: 18: current per tree log-likelihood -6.428984
# Iter: 19: current per tree log-likelihood -6.426079
# Iter: 20: current per tree log-likelihood -6.423503
# Iter: 21: current per tree log-likelihood -6.421531
# Iter: 22: current per tree log-likelihood -6.419935
# Iter: 23: current per tree log-likelihood -6.418151
# Iter: 24: current per tree log-likelihood -6.416023
# Iter: 25: current per tree log-likelihood -6.414104
# Iter: 26: current per tree log-likelihood -6.412873
# Iter: 27: current per tree log-likelihood -6.411849
# Iter: 28: current per tree log-likelihood -6.410798
# Iter: 29: current per tree log-likelihood -6.410027
# Iter: 30: current per tree log-likelihood -6.409489
# Iter: 31: current per tree log-likelihood -6.409102
# Iter: 32: current per tree log-likelihood -6.408729
# Iter: 33: current per tree log-likelihood -6.408349
# Iter: 34: current per tree log-likelihood -6.408012
# Iter: 35: current per tree log-likelihood -6.407753
# Iter: 36: current per tree log-likelihood -6.407514
# Iter: 37: current per tree log-likelihood -6.407267
# Iter: 38: current per tree log-likelihood -6.407011
# Iter: 39: current per tree log-likelihood -6.406755
# Iter: 40: current per tree log-likelihood -6.406511
# Iter: 41: current per tree log-likelihood -6.406279
# Iter: 42: current per tree log-likelihood -6.406066
# Iter: 43: current per tree log-likelihood -6.405872
# Iter: 44: current per tree log-likelihood -6.405702
# Iter: 45: current per tree log-likelihood -6.405559
# Iter: 46: current per tree log-likelihood -6.405422
# Iter: 47: current per tree log-likelihood -6.405288
# Iter: 48: current per tree log-likelihood -6.405155
# Iter: 49: current per tree log-likelihood -6.405023
# Iter: 50: current per tree log-likelihood -6.404901
# Iter: 51: current per tree log-likelihood -6.404798
# Iter: 52: current per tree log-likelihood -6.404705
# Iter: 53: current per tree log-likelihood -6.404615
# Iter: 54: current per tree log-likelihood -6.404525
# Iter: 55: current per tree log-likelihood -6.404437
# Iter: 56: current per tree log-likelihood -6.404351
# Iter: 57: current per tree log-likelihood -6.404265
# Iter: 58: current per tree log-likelihood -6.404181
# Iter: 59: current per tree log-likelihood -6.404094
# Iter: 60: current per tree log-likelihood -6.404004
# Iter: 61: current per tree log-likelihood -6.403909
# Iter: 62: current per tree log-likelihood -6.403809
# Iter: 63: current per tree log-likelihood -6.403713
# Iter: 64: current per tree log-likelihood -6.403641
# Iter: 65: current per tree log-likelihood -6.403591
# Iter: 66: current per tree log-likelihood -6.403544
# Iter: 67: current per tree log-likelihood -6.403497
# Iter: 68: current per tree log-likelihood -6.403449
# Iter: 69: current per tree log-likelihood -6.403402
# Iter: 70: current per tree log-likelihood -6.403354
# Iter: 71: current per tree log-likelihood -6.403305
# Iter: 72: current per tree log-likelihood -6.403251
# Iter: 73: current per tree log-likelihood -6.403173
# Iter: 74: current per tree log-likelihood -6.403038
# Iter: 75: current per tree log-likelihood -6.402904
# Iter: 76: current per tree log-likelihood -6.402825
# Iter: 77: current per tree log-likelihood -6.402762
# Iter: 78: current per tree log-likelihood -6.402697
# Iter: 79: current per tree log-likelihood -6.402625
# Iter: 80: current per tree log-likelihood -6.402545
# Iter: 81: current per tree log-likelihood -6.402457
# Iter: 82: current per tree log-likelihood -6.402367
# Iter: 83: current per tree log-likelihood -6.402292
# Iter: 84: current per tree log-likelihood -6.402243
# Iter: 85: current per tree log-likelihood -6.402205
# Iter: 86: current per tree log-likelihood -6.402170
# Iter: 87: current per tree log-likelihood -6.402139
# Iter: 88: current per tree log-likelihood -6.402112
# Iter: 89: current per tree log-likelihood -6.402087
# Iter: 90: current per tree log-likelihood -6.402065
# Iter: 91: current per tree log-likelihood -6.402044
# Iter: 92: current per tree log-likelihood -6.402024
# Iter: 93: current per tree log-likelihood -6.402004
# Iter: 94: current per tree log-likelihood -6.401984
# Iter: 95: current per tree log-likelihood -6.401964
# Iter: 96: current per tree log-likelihood -6.401944
# Iter: 97: current per tree log-likelihood -6.401925
# Iter: 98: current per tree log-likelihood -6.401905
# Iter: 99: current per tree log-likelihood -6.401885
# Iter: 100: current per tree log-likelihood -6.401866
# Iter: 101: current per tree log-likelihood -6.401847
# Iter: 102: current per tree log-likelihood -6.401827
# Iter: 103: current per tree log-likelihood -6.401808
# Iter: 104: current per tree log-likelihood -6.401789
# Iter: 105: current per tree log-likelihood -6.401769
# Iter: 106: current per tree log-likelihood -6.401750
# Iter: 107: current per tree log-likelihood -6.401731
# Iter: 108: current per tree log-likelihood -6.401711
# Iter: 109: current per tree log-likelihood -6.401692
# Iter: 110: current per tree log-likelihood -6.401673
# Iter: 111: current per tree log-likelihood -6.401653
# Iter: 112: current per tree log-likelihood -6.401633
# Iter: 113: current per tree log-likelihood -6.401613
# Iter: 114: current per tree log-likelihood -6.401593
# Iter: 115: current per tree log-likelihood -6.401572
# Iter: 116: current per tree log-likelihood -6.401551
# Iter: 117: current per tree log-likelihood -6.401528
# Iter: 118: current per tree log-likelihood -6.401504
# Iter: 119: current per tree log-likelihood -6.401477
# Iter: 120: current per tree log-likelihood -6.401448
# Iter: 121: current per tree log-likelihood -6.401414
# Iter: 122: current per tree log-likelihood -6.401375
# Iter: 123: current per tree log-likelihood -6.401330
# Iter: 124: current per tree log-likelihood -6.401277
# Iter: 125: current per tree log-likelihood -6.401218
# Iter: 126: current per tree log-likelihood -6.401156
# Iter: 127: current per tree log-likelihood -6.401096
# Iter: 128: current per tree log-likelihood -6.401043
# Iter: 129: current per tree log-likelihood -6.400999
# Iter: 130: current per tree log-likelihood -6.400965
# Iter: 131: current per tree log-likelihood -6.400938
# Iter: 132: current per tree log-likelihood -6.400917
# Iter: 133: current per tree log-likelihood -6.400899
# Iter: 134: current per tree log-likelihood -6.400883
# Iter: 135: current per tree log-likelihood -6.400868
# Iter: 136: current per tree log-likelihood -6.400854
# Iter: 137: current per tree log-likelihood -6.400841
# Iter: 138: current per tree log-likelihood -6.400828
# Iter: 139: current per tree log-likelihood -6.400815
# Iter: 140: current per tree log-likelihood -6.400802
# Iter: 141: current per tree log-likelihood -6.400789
# Iter: 142: current per tree log-likelihood -6.400776
# Iter: 143: current per tree log-likelihood -6.400763
# Iter: 144: current per tree log-likelihood -6.400750
# Iter: 145: current per tree log-likelihood -6.400738
# Iter: 146: current per tree log-likelihood -6.400726
# Iter: 147: current per tree log-likelihood -6.400713
# Iter: 148: current per tree log-likelihood -6.400701
# Iter: 149: current per tree log-likelihood -6.400689
# Iter: 150: current per tree log-likelihood -6.400677
# Iter: 151: current per tree log-likelihood -6.400665
# Iter: 152: current per tree log-likelihood -6.400653
# Iter: 153: current per tree log-likelihood -6.400641
# Iter: 154: current per tree log-likelihood -6.400629
# Iter: 155: current per tree log-likelihood -6.400618
# Iter: 156: current per tree log-likelihood -6.400606
# Iter: 157: current per tree log-likelihood -6.400595
# Iter: 158: current per tree log-likelihood -6.400584
# Iter: 159: current per tree log-likelihood -6.400572
# Iter: 160: current per tree log-likelihood -6.400561
# Iter: 161: current per tree log-likelihood -6.400550
# Iter: 162: current per tree log-likelihood -6.400539
# Iter: 163: current per tree log-likelihood -6.400528
# Iter: 164: current per tree log-likelihood -6.400517
# Iter: 165: current per tree log-likelihood -6.400506
# Iter: 166: current per tree log-likelihood -6.400495
# Iter: 167: current per tree log-likelihood -6.400484
# Iter: 168: current per tree log-likelihood -6.400473
# Iter: 169: current per tree log-likelihood -6.400462
# Iter: 170: current per tree log-likelihood -6.400451
# Iter: 171: current per tree log-likelihood -6.400440
# Iter: 172: current per tree log-likelihood -6.400429
# Iter: 173: current per tree log-likelihood -6.400418
# Iter: 174: current per tree log-likelihood -6.400407
# Iter: 175: current per tree log-likelihood -6.400396
# Iter: 176: current per tree log-likelihood -6.400386
# Iter: 177: current per tree log-likelihood -6.400375
# Iter: 178: current per tree log-likelihood -6.400364
# Iter: 179: current per tree log-likelihood -6.400353
# Iter: 180: current per tree log-likelihood -6.400342
# Iter: 181: current per tree log-likelihood -6.400331
# Iter: 182: current per tree log-likelihood -6.400320
# Iter: 183: current per tree log-likelihood -6.400310
# Iter: 184: current per tree log-likelihood -6.400299
# Iter: 185: current per tree log-likelihood -6.400288
# Iter: 186: current per tree log-likelihood -6.400277
# Iter: 187: current per tree log-likelihood -6.400266
# Iter: 188: current per tree log-likelihood -6.400255
# Iter: 189: current per tree log-likelihood -6.400245
# Iter: 190: current per tree log-likelihood -6.400234
# Iter: 191: current per tree log-likelihood -6.400223
# Iter: 192: current per tree log-likelihood -6.400212
# Iter: 193: current per tree log-likelihood -6.400201
# Iter: 194: current per tree log-likelihood -6.400191
# Iter: 195: current per tree log-likelihood -6.400180
# Iter: 196: current per tree log-likelihood -6.400169
# Iter: 197: current per tree log-likelihood -6.400158
# Iter: 198: current per tree log-likelihood -6.400147
# Iter: 199: current per tree log-likelihood -6.400137
# Iter: 200: current per tree log-likelihood -6.400126

# %%
kl_div_mean = np.mean(kl_div_mat, axis=0)
kl_div_std = np.std(kl_div_mat, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 kl_div_mean = np.mean(kl_div_mat, axis=0)
#       2 kl_div_std = np.std(kl_div_mat, axis=0)
#
# NameError: name 'kl_div_mat' is not defined

# %%
fig = plt.figure(figsize=(17, 4))
gs1 = gridspec.GridSpec(1,2)
gs1.update(left=0.02, right=0.46, wspace=0.3)
ax0 = plt.subplot(gs1[0,0])
ccd_kl_div = kl_div_mean[:,:,0]
im = ax0.imshow(ccd_kl_div, origin='lower', cmap='jet', norm=LogNorm(vmin=kl_div_mean.min(), vmax=kl_div_mean.max()))
cbar = plt.colorbar(im, ax=ax0)
ax0.set_aspect('auto')
ax0.set_xticks(range(5))
ax0.set_yticks(range(6))
ax0.set_xticks(np.arange(-0.5,5,1), minor=True)
ax0.set_yticks(np.arange(-0.5,6,1), minor=True)
ax0.set_xticklabels([500, 1000, 2000, 4000, 8000])
ax0.set_yticklabels([0.001,0.002,0.004,0.008,0.016,0.032])
ax0.grid(which='minor')
ax0.tick_params(labelsize=12)
ax0.set_xlabel(r'$K$', fontsize=14)
ax0.set_ylabel(r'$\beta$', fontsize=14)
ax0.set_title('CCD', fontsize=16, y=1.02)


ax1 = plt.subplot(gs1[0,1])
sbn_em_kl_div = kl_div_mean[:,:,2]
im = ax1.imshow(sbn_em_kl_div, origin='lower', cmap='jet', norm=LogNorm(vmin=kl_div_mean.min(), vmax=kl_div_mean.max()))
cbar = plt.colorbar(im, ax=ax1)
ax1.set_aspect('auto')
ax1.set_xticks(range(5))
ax1.set_yticks(range(6))
ax1.set_xticks(np.arange(-0.5,5,1), minor=True)
ax1.set_yticks(np.arange(-0.5,6,1), minor=True)
ax1.set_xticklabels([500, 1000, 2000, 4000, 8000])
ax1.set_yticklabels([0.001,0.002,0.004,0.008,0.016,0.032])
ax1.grid(which='minor')
ax1.tick_params(labelsize=12)
ax1.set_xlabel(r'$K$', fontsize=14)
ax1.set_title('SBN-EM', fontsize=16, y=1.02)

gs2 = gridspec.GridSpec(1,2)
gs2.update(left=0.54, right=0.98, wspace=0.2)
ax2 = plt.subplot(gs2[0,0])

labels={0:'ccd',1:'sbn-sa',2:'sbn-em',3:'sbn-em-'+r'$\alpha$',4:'srf'}
fmts={0:'-o',1:'-s',2:'-d',3:'-^',4:'--'}
marksz={0:5,1:5,2:6,3:6,4:0}

beta_v = [0.001, 0.002, 0.004, 0.008, 0.016, 0.032]
k = 3
ax2.set_xscale('log')
for i in [0,1,2,3,4]:
    ax2.errorbar(beta_v, kl_div_mean[:,k,i], yerr=kl_div_std[:,k,i], c=colors[i], label=labels[i], fmt=fmts[i],markersize=marksz[i], alpha=0.75, linewidth=1)

leg = ax2.legend(loc='best',fontsize=14)
leg.get_frame().set_alpha(0.5)
ax2.grid(which='both', linestyle='--', alpha=0.5)
ax2.tick_params(labelsize=12)
ax2.set_xlabel(r'$\beta$', fontsize=14)
ax2.set_ylabel('KL divergence', fontsize=14)
ax2.set_title(r'$K=4000$', y=1.02, fontsize=16)
ax2.set_ylim(top=3)

ax3 = plt.subplot(gs2[0,1])
K_v = [500, 1000, 2000, 4000, 8000]
l = 3
ax3.set_xscale('log')

for i in [0,1,2,3,4]:
    ax3.errorbar(K_v, kl_div_mean[l,:,i], yerr=kl_div_std[l,:,i], c=colors[i], label=labels[i], fmt=fmts[i], markersize=marksz[i], alpha=0.75, linewidth=1)

leg = ax3.legend(loc='best',fontsize=14)
leg.get_frame().set_alpha(0.5)
ax3.grid(which='both', linestyle='--', alpha=0.5)
ax3.tick_params(labelsize=12)
ax3.set_xlabel(r'$K$', fontsize=14)
ax3.set_title(r'$\beta=0.008$', y=1.02, fontsize=16)
plt.show()
